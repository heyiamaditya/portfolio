# %% [markdown]
# <a href="https://colab.research.google.com/github/heyiamaditya/portfolio/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_excel("/content/191b021.xlsx")
# Out:
#    Unnamed: 0  ... Unnamed: 11
# 0         NaN  ...         NaN
# 1         NaN  ...         NaN
# 2         NaN  ...         NaN
# 3         NaN  ...         NaN
# 4         NaN  ...         NaN
# 5         NaN  ...         NaN
# 6         NaN  ...         NaN
# 7         Q1.  ...     5 marks
# 8         NaN  ...         NaN
# 9         NaN  ...         NaN
# 10        NaN  ...         NaN
# 11        NaN  ...         NaN
# 12        NaN  ...         NaN
# 13        NaN  ...         NaN
# 14        NaN  ...         NaN
# 15        NaN  ...         NaN
# 16        NaN  ...         NaN
# 17        NaN  ...         NaN
# 18        NaN  ...         NaN
# 19        Q2.  ...     4 marks
# 20        NaN  ...         NaN
# 21        NaN  ...         NaN
# 22        NaN  ...         NaN
# 23        NaN  ...         NaN
# 24        NaN  ...         NaN
# 25        NaN  ...         NaN
# 26        NaN  ...         NaN
# 27        NaN  ...         NaN
# 28        NaN  ...         NaN
# ...
